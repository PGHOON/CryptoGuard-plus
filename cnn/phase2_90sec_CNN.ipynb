# %%
import os
import glob
import numpy as np
import pandas as pd
import tensorflow as tf

from multiprocessing import Pool

from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Conv1D, Flatten, Dense, Permute
from tensorflow.keras.regularizers import l2

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from numpy.lib.stride_tricks import as_strided
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788834765.386532   61472 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## System Calls List

# %%
syscalls = [
"sys_enter_llistxattr",
"sys_enter_setgroups",
"sys_enter_lremovexattr",
"sys_enter_sethostname",
"sys_enter_accept",
"sys_enter_lseek",
"sys_enter_setitimer",
"sys_enter_accept4",
"sys_enter_lsetxattr",
"sys_enter_setns",
"sys_enter_acct",
"sys_enter_madvise",
"sys_enter_setpgid",
"sys_enter_add_key",
"sys_enter_mbind",
"sys_enter_setpriority",
"sys_enter_adjtimex",
"sys_enter_membarrier",
"sys_enter_setregid",
"sys_enter_personality",
"sys_enter_memfd_create",
"sys_enter_setresgid",
"sys_enter_bind",
"sys_enter_memfd_secret",
"sys_enter_setresuid",
"sys_enter_bpf",
"sys_enter_migrate_pages",
"sys_enter_setreuid",
"sys_enter_brk",
"sys_enter_mincore",
"sys_enter_setrlimit",
"sys_enter_capget",
"sys_enter_mkdirat",
"sys_enter_setsid",
"sys_enter_capset",
"sys_enter_mknodat",
"sys_enter_setsockopt",
"sys_enter_chdir",
"sys_enter_mlock",
"sys_enter_settimeofday",
"sys_enter_chroot",
"sys_enter_mlock2",
"sys_enter_setuid",
"sys_enter_clock_adjtime",
"sys_enter_mlockall",
"sys_enter_setxattr",
"sys_enter_clock_getres",
"sys_enter_mmap",
"sys_enter_shmat",
"sys_enter_clock_gettime",
"sys_enter_mount",
"sys_enter_shmctl",
"sys_enter_clock_nanosleep",
"sys_enter_mount_setattr",
"sys_enter_shmdt",
"sys_enter_clock_settime",
"sys_enter_move_mount",
"sys_enter_shmget",
"sys_enter_clone",
"sys_enter_move_pages",
"sys_enter_shutdown",
"sys_enter_clone3",
"sys_enter_mprotect",
"sys_enter_sigaltstack",
"sys_enter_close",
"sys_enter_mq_getsetattr",
"sys_enter_signalfd4",
"sys_enter_close_range",
"sys_enter_mq_notify",
"sys_enter_socket",
"sys_enter_connect",
"sys_enter_mq_open",
"sys_enter_socketpair",
"sys_enter_copy_file_range",
"sys_enter_mq_timedreceive",
"sys_enter_splice",
"sys_enter_delete_module",
"sys_enter_mq_timedsend",
"sys_enter_statfs",
"sys_enter_dup",
"sys_enter_mq_unlink",
"sys_enter_statx",
"sys_enter_dup3",
"sys_enter_mremap",
"sys_enter_swapoff",
"sys_enter_epoll_create1",
"sys_enter_msgctl",
"sys_enter_swapon",
"sys_enter_epoll_ctl",
"sys_enter_msgget",
"sys_enter_symlinkat",
"sys_enter_epoll_pwait",
"sys_enter_msgrcv",
"sys_enter_sync",
"sys_enter_epoll_pwait2",
"sys_enter_msgsnd",
"sys_enter_sync_file_range",
"sys_enter_eventfd2",
"sys_enter_msync",
"sys_enter_syncfs",
"sys_enter_execve",
"sys_enter_munlock",
"sys_enter_sysinfo",
"sys_enter_execveat",
"sys_enter_munlockall",
"sys_enter_syslog",
"sys_enter_exit",
"sys_enter_munmap",
"sys_enter_tee",
"sys_enter_exit_group",
"sys_enter_name_to_handle_at",
"sys_enter_tgkill",
"sys_enter_faccessat",
"sys_enter_nanosleep",
"sys_enter_timer_create",
"sys_enter_faccessat2",
"sys_enter_newfstat",
"sys_enter_timer_delete",
"sys_enter_fadvise64",
"sys_enter_newfstatat",
"sys_enter_timer_getoverrun",
"sys_enter_fallocate",
"sys_enter_newuname",
"sys_enter_timer_gettime",
"sys_enter_fanotify_init",
"sys_enter_open_by_handle_at",
"sys_enter_timer_settime",
"sys_enter_fanotify_mark",
"sys_enter_open_tree",
"sys_enter_timerfd_create",
"sys_enter_fchdir",
"sys_enter_openat",
"sys_enter_timerfd_gettime",
"sys_enter_fchmod",
"sys_enter_openat2",
"sys_enter_timerfd_settime",
"sys_enter_fchmodat",
"sys_enter_perf_event_open",
"sys_enter_times",
"sys_enter_fchown",
"sys_enter_pidfd_getfd",
"sys_enter_tkill",
"sys_enter_fchownat",
"sys_enter_pidfd_open",
"sys_enter_truncate",
"sys_enter_fcntl",
"sys_enter_pidfd_send_signal",
"sys_enter_umask",
"sys_enter_fdatasync",
"sys_enter_pipe2",
"sys_enter_umount",
"sys_enter_fgetxattr",
"sys_enter_pivot_root",
"sys_enter_unlinkat",
"sys_enter_finit_module",
"sys_enter_ppoll",
"sys_enter_unshare",
"sys_enter_flistxattr",
"sys_enter_prctl",
"sys_enter_userfaultfd",
"sys_enter_flock",
"sys_enter_pread64",
"sys_enter_utimensat",
"sys_enter_fremovexattr",
"sys_enter_preadv",
"sys_enter_vhangup",
"sys_enter_fsconfig",
"sys_enter_preadv2",
"sys_enter_vmsplice",
"sys_enter_fsetxattr",
"sys_enter_prlimit64",
"sys_enter_wait4",
"sys_enter_fsmount",
"sys_enter_process_madvise",
"sys_enter_waitid",
"sys_enter_fsopen",
"sys_enter_process_mrelease",
"sys_enter_write",
"sys_enter_fspick",
"sys_enter_process_vm_readv",
"sys_enter_writev",
"sys_enter_fstatfs",
"sys_enter_process_vm_writev",
"sys_enter_fsync",
"sys_enter_pselect6",
"sys_enter_ftruncate",
"sys_enter_ptrace",
"sys_enter_futex",
"sys_enter_pwrite64",
"sys_enter_get_mempolicy",
"sys_enter_pwritev",
"sys_enter_get_robust_list",
"sys_enter_pwritev2",
"sys_enter_getcpu",
"sys_enter_quotactl",
"sys_enter_getcwd",
"sys_enter_quotactl_fd",
"sys_enter_getdents64",
"sys_enter_read",
"sys_enter_getegid",
"sys_enter_readahead",
"sys_enter_geteuid",
"sys_enter_readlinkat",
"sys_enter_getgid",
"sys_enter_readv",
"sys_enter_getgroups",
"sys_enter_reboot",
"sys_enter_getitimer",
"sys_enter_recvfrom",
"sys_enter_getpeername",
"sys_enter_recvmmsg",
"sys_enter_getpgid",
"sys_enter_recvmsg",
"sys_enter_getpid",
"sys_enter_remap_file_pages",
"sys_enter_getppid",
"sys_enter_removexattr",
"sys_enter_getpriority",
"sys_enter_renameat",
"sys_enter_getrandom",
"sys_enter_renameat2",
"sys_enter_getresgid",
"sys_enter_request_key",
"sys_enter_getresuid",
"sys_enter_restart_syscall",
"sys_enter_getrlimit",
"sys_enter_rseq",
"sys_enter_getrusage",
"sys_enter_rt_sigaction",
"sys_enter_getsid",
"sys_enter_rt_sigpending",
"sys_enter_getsockname",
"sys_enter_rt_sigprocmask",
"sys_enter_getsockopt",
"sys_enter_rt_sigqueueinfo",
"sys_enter_gettid",
"sys_enter_rt_sigreturn",
"sys_enter_gettimeofday",
"sys_enter_rt_sigsuspend",
"sys_enter_getuid",
"sys_enter_rt_sigtimedwait",
"sys_enter_getxattr",
"sys_enter_rt_tgsigqueueinfo",
"sys_enter_init_module",
"sys_enter_sched_get_priority_max",
"sys_enter_inotify_add_watch",
"sys_enter_sched_get_priority_min",
"sys_enter_inotify_init1",
"sys_enter_sched_getaffinity",
"sys_enter_inotify_rm_watch",
"sys_enter_sched_getattr",
"sys_enter_io_cancel",
"sys_enter_sched_getparam",
"sys_enter_io_destroy",
"sys_enter_sched_getscheduler",
"sys_enter_io_getevents",
"sys_enter_sched_rr_get_interval",
"sys_enter_io_pgetevents",
"sys_enter_sched_setaffinity",
"sys_enter_io_setup",
"sys_enter_sched_setattr",
"sys_enter_io_submit",
"sys_enter_sched_setparam",
"sys_enter_io_uring_enter",
"sys_enter_sched_setscheduler",
"sys_enter_io_uring_register",
"sys_enter_sched_yield",
"sys_enter_io_uring_setup",
"sys_enter_seccomp",
"sys_enter_ioctl",
"sys_enter_semctl",
"sys_enter_ioprio_get",
"sys_enter_semget",
"sys_enter_ioprio_set",
"sys_enter_semop",
"sys_enter_kcmp",
"sys_enter_semtimedop",
"sys_enter_kexec_file_load",
"sys_enter_sendfile64",
"sys_enter_kexec_load",
"sys_enter_sendmmsg",
"sys_enter_keyctl",
"sys_enter_sendmsg",
"sys_enter_kill",
"sys_enter_sendto",
"sys_enter_landlock_add_rule",
"sys_enter_set_mempolicy",
"sys_enter_landlock_create_ruleset",
"sys_enter_set_robust_list",
"sys_enter_landlock_restrict_self",
"sys_enter_set_tid_address",
"sys_enter_lgetxattr",
"sys_enter_setdomainname",
"sys_enter_linkat",
"sys_enter_setfsgid",
"sys_enter_listen",
"sys_enter_setfsuid",
"sys_enter_listxattr",
"sys_enter_setgid"
]

# %% [markdown]
# ## Loading CSV from Desktop

# %%
NUM_CLASSES = 4
CLASSES = np.array(['benign', 'sysrv', 'xmrig', 'mirai'])
DATASET_DIR = "../dataset/phase2"
VECTOR_LENGTH = 32 * 32
DT = 90

label_encoder = LabelEncoder()
label_encoder.fit(syscalls)

def csvToVector(file_path):
    try:
        data = pd.read_csv(file_path, encoding='utf-8')
    except UnicodeDecodeError:
        data = pd.read_csv(file_path, encoding='ISO-8859-1')

    data_encoded = label_encoder.fit_transform(data['SYSTEM_CALL'])
    vector = np.zeros(VECTOR_LENGTH, dtype=np.float32)
    syscall_nums = min(len(data_encoded), VECTOR_LENGTH)
    vector[:syscall_nums] = data_encoded[:syscall_nums]

    return vector / 299.0

def process_file(args):
    file_path, class_idx = args
    vector = csvToVector(file_path)
    return vector, class_idx

def load_data(dataset_dir):
    x = []
    y = []
    classes = [f"0/{DT}sec_0", f"1/{DT}sec_1", f"2/{DT}sec_2", f"3/{DT}sec_3"]

    file_paths = []
    for class_idx, class_name in enumerate(classes):
        class_dir = os.path.join(dataset_dir, class_name)
        for file_name in os.listdir(class_dir):
            if file_name.endswith('.csv'):
                file_path = os.path.join(class_dir, file_name)
                file_paths.append((file_path, class_idx))

    with Pool() as pool:
        results = pool.map(process_file, file_paths)

    x, y = zip(*results)
    x = np.array(x)
    y = np.array(y)

    return x, y

# %%
X, y = load_data(DATASET_DIR)

# %% [markdown]
# ## Train, Validation, Test Split and Normalize

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

X_train = X_train.reshape(-1, VECTOR_LENGTH, 1)
X_val = X_val.reshape(-1, VECTOR_LENGTH, 1)
X_test = X_test.reshape(-1, VECTOR_LENGTH, 1)

classes = np.unique(y_train)
weights = compute_class_weight('balanced', classes=classes, y=y_train)
class_weight = {int(c): float(w) for c, w in zip(classes, weights)}

# %% [markdown]
# ## 1D CNN model

# %%
input_layer = Input(shape=(VECTOR_LENGTH, 1))

x = Conv1D(filters=16, kernel_size=3, strides=10, padding='valid', activation='relu')(input_layer)
x = Conv1D(filters=32, kernel_size=3, strides=1, padding='valid', activation='relu')(x)
x = Conv1D(filters=64, kernel_size=3, strides=1, padding='valid', activation='relu')(x)

x = Permute((2, 1))(x)
x = Flatten()(x)

x = Dense(32, activation='relu', kernel_regularizer=l2(1e-4))(x)
output_layer = Dense(NUM_CLASSES, activation='softmax', kernel_regularizer=l2(1e-4))(x)

model = Model(input_layer, output_layer)

opt = Adam(learning_rate=0.001)
model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ## Check Point

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, min_lr=0.00001)
checkpoint = ModelCheckpoint(
    filepath='./phase2_90sec.h5',
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

# %% [markdown]
# ## Model Training

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), class_weight=class_weight, callbacks=[reduce_lr, checkpoint])
# Out:
# Epoch 1/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4291 - loss: 1.2351
# Epoch 1: val_accuracy improved from None to 0.59091, saving model to ./phase2_90sec.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to ./phase2_90sec.h5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4506 - loss: 1.2129 - val_accuracy: 0.5909 - val_loss: 1.1319 - learning_rate: 0.0010
# Epoch 2/100
# 42/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7076 - loss: 0.9708
# Epoch 2: val_accuracy improved from 0.59091 to 0.85511, saving model to ./phase2_90sec.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: finished saving model to ./phase2_90sec.h5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7136 - loss: 0.9660 - val_accuracy: 0.8551 - val_loss: 0.8877 - learning_rate: 0.0010
# Epoch 3/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8361 - loss: 0.7817
# Epoch 3: val_accuracy did not improve from 0.85511
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8365 - loss: 0.7716 - val_accuracy: 0.8551 - val_loss: 0.7652 - learning_rate: 0.0010
# Epoch 4/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8678 - loss: 0.6399
# Epoch 4: val_accuracy improved from 0.85511 to 0.88068, saving model to ./phase2_90sec.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: finished saving model to ./phase2_90sec.h5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8643 - loss: 0.6370 - val_accuracy: 0.8807 - val_loss: 0.5810 - learning_rate: 0.0010
# Epoch 5/100
# 43/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8735 - loss: 0.5027
# Epoch 5: val_accuracy did not improve from 0.88068
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8749 - loss: 0.4979 - val_accuracy: 0.8807 - val_loss: 0.4665 - learning_rate: 0.0010
# Epoch 6/100
# 36/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8776 - loss: 0.4505
# Epoch 6: val_accuracy did not improve from 0.88068
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8856 - loss: 0.4283 - val_accuracy: 0.7812 - val_loss: 0.5152 - learning_rate: 0.0010
# Epoch 7/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8982 - loss: 0.4036
# Epoch 7: val_accuracy improved from 0.88068 to 0.90341, saving model to ./phase2_90sec.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: finished saving model to ./phase2_90sec.h5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8998 - loss: 0.3960 - val_accuracy: 0.9034 - val_loss: 0.4435 - learning_rate: 0.0010
# Epoch 8/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9022 - loss: 0.3682
# Epoch 8: val_accuracy did not improve from 0.90341
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8984 - loss: 0.3796 - val_accuracy: 0.8977 - val_loss: 0.4218 - learning_rate: 0.0010
# Epoch 9/100
# 42/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9025 - loss: 0.3650
# Epoch 9: val_accuracy did not improve from 0.90341
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9019 - loss: 0.3747 - val_accuracy: 0.8835 - val_loss: 0.4367 - learning_rate: 0.0010
# Epoch 10/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8978 - loss: 0.3598
# Epoch 10: val_accuracy did not improve from 0.90341
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8977 - loss: 0.3534 - val_accuracy: 0.8920 - val_loss: 0.4105 - learning_rate: 0.0010
# Epoch 11/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8970 - loss: 0.3737
# Epoch 11: val_accuracy improved from 0.90341 to 0.91193, saving model to ./phase2_90sec.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 11: finished saving model to ./phase2_90sec.h5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8977 - loss: 0.3714 - val_accuracy: 0.9119 - val_loss: 0.4109 - learning_rate: 0.0010
# Epoch 12/100
# 38/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9038 - loss: 0.3406
# Epoch 12: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9083 - loss: 0.3299 - val_accuracy: 0.9006 - val_loss: 0.4066 - learning_rate: 0.0010
# Epoch 13/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8982 - loss: 0.3340
# Epoch 13: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8977 - loss: 0.3363 - val_accuracy: 0.8977 - val_loss: 0.4228 - learning_rate: 0.0010
# Epoch 14/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9123 - loss: 0.3071
# Epoch 14: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9112 - loss: 0.3111 - val_accuracy: 0.8778 - val_loss: 0.4001 - learning_rate: 0.0010
# Epoch 15/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9103 - loss: 0.2944
# Epoch 15: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9076 - loss: 0.3035 - val_accuracy: 0.8977 - val_loss: 0.4072 - learning_rate: 0.0010
# Epoch 16/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9133 - loss: 0.2935
# Epoch 16: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9126 - loss: 0.2951 - val_accuracy: 0.8949 - val_loss: 0.4075 - learning_rate: 0.0010
# Epoch 17/100
# 38/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9145 - loss: 0.2853
# Epoch 17: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9133 - loss: 0.2850 - val_accuracy: 0.8807 - val_loss: 0.4027 - learning_rate: 0.0010
# Epoch 18/100
# 43/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9208 - loss: 0.2797
# Epoch 18: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9204 - loss: 0.2832 - val_accuracy: 0.9091 - val_loss: 0.3951 - learning_rate: 0.0010
# Epoch 19/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9169 - loss: 0.2818
# Epoch 19: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9161 - loss: 0.2862 - val_accuracy: 0.8892 - val_loss: 0.3749 - learning_rate: 0.0010
# Epoch 20/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9181 - loss: 0.2573
# Epoch 20: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9168 - loss: 0.2592 - val_accuracy: 0.9062 - val_loss: 0.3675 - learning_rate: 0.0010
# Epoch 21/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9200 - loss: 0.2542
# Epoch 21: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9218 - loss: 0.2505 - val_accuracy: 0.9062 - val_loss: 0.3809 - learning_rate: 0.0010
# Epoch 22/100
# 43/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9237 - loss: 0.2451
# Epoch 22: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9240 - loss: 0.2448 - val_accuracy: 0.9091 - val_loss: 0.3482 - learning_rate: 0.0010
# Epoch 23/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9327 - loss: 0.2338
# Epoch 23: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9296 - loss: 0.2379 - val_accuracy: 0.8864 - val_loss: 0.3951 - learning_rate: 0.0010
# Epoch 24/100
# 38/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9301 - loss: 0.2190
# Epoch 24: val_accuracy did not improve from 0.91193
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9289 - loss: 0.2271 - val_accuracy: 0.9062 - val_loss: 0.3833 - learning_rate: 0.0010
# Epoch 25/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9279 - loss: 0.2388
# Epoch 25: val_accuracy improved from 0.91193 to 0.91477, saving model to ./phase2_90sec.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 25: finished saving model to ./phase2_90sec.h5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9282 - loss: 0.2354 - val_accuracy: 0.9148 - val_loss: 0.4386 - learning_rate: 0.0010
# Epoch 26/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9295 - loss: 0.2348
# Epoch 26: val_accuracy did not improve from 0.91477
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9325 - loss: 0.2266 - val_accuracy: 0.9119 - val_loss: 0.3832 - learning_rate: 0.0010
# Epoch 27/100
# 38/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9252 - loss: 0.2318
# Epoch 27: val_accuracy did not improve from 0.91477
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9247 - loss: 0.2313 - val_accuracy: 0.8466 - val_loss: 0.4280 - learning_rate: 0.0010
# Epoch 28/100
# 38/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9285 - loss: 0.2180
# Epoch 28: val_accuracy did not improve from 0.91477
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9268 - loss: 0.2171 - val_accuracy: 0.8892 - val_loss: 0.4315 - learning_rate: 0.0010
# Epoch 29/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9351 - loss: 0.2164
# Epoch 29: val_accuracy did not improve from 0.91477
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9367 - loss: 0.2153 - val_accuracy: 0.9006 - val_loss: 0.3834 - learning_rate: 0.0010
# Epoch 30/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9335 - loss: 0.2049
# Epoch 30: val_accuracy improved from 0.91477 to 0.91761, saving model to ./phase2_90sec.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 30: finished saving model to ./phase2_90sec.h5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9375 - loss: 0.2013 - val_accuracy: 0.9176 - val_loss: 0.3717 - learning_rate: 0.0010
# Epoch 31/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9344 - loss: 0.1968
# Epoch 31: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9353 - loss: 0.1926 - val_accuracy: 0.9119 - val_loss: 0.3547 - learning_rate: 5.0000e-04
# Epoch 32/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9410 - loss: 0.1769
# Epoch 32: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9410 - loss: 0.1769 - val_accuracy: 0.9176 - val_loss: 0.3662 - learning_rate: 5.0000e-04
# Epoch 33/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9463 - loss: 0.1672
# Epoch 33: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9460 - loss: 0.1727 - val_accuracy: 0.8977 - val_loss: 0.3778 - learning_rate: 5.0000e-04
# Epoch 34/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9436 - loss: 0.1682
# Epoch 34: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9431 - loss: 0.1709 - val_accuracy: 0.9006 - val_loss: 0.3668 - learning_rate: 5.0000e-04
# Epoch 35/100
# 38/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9465 - loss: 0.1684
# Epoch 35: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9474 - loss: 0.1655 - val_accuracy: 0.8949 - val_loss: 0.3610 - learning_rate: 5.0000e-04
# Epoch 36/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9484 - loss: 0.1555
# Epoch 36: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9481 - loss: 0.1608 - val_accuracy: 0.9034 - val_loss: 0.3651 - learning_rate: 5.0000e-04
# Epoch 37/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9423 - loss: 0.1625
# Epoch 37: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9446 - loss: 0.1610 - val_accuracy: 0.9091 - val_loss: 0.3481 - learning_rate: 5.0000e-04
# Epoch 38/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9488 - loss: 0.1620
# Epoch 38: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9488 - loss: 0.1620 - val_accuracy: 0.9091 - val_loss: 0.3547 - learning_rate: 5.0000e-04
# Epoch 39/100
# 43/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9520 - loss: 0.1635
# Epoch 39: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9524 - loss: 0.1623 - val_accuracy: 0.8977 - val_loss: 0.3656 - learning_rate: 5.0000e-04
# Epoch 40/100
# 42/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9457 - loss: 0.1618
# Epoch 40: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9474 - loss: 0.1591 - val_accuracy: 0.9062 - val_loss: 0.3498 - learning_rate: 5.0000e-04
# Epoch 41/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9477 - loss: 0.1661
# Epoch 41: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9474 - loss: 0.1684 - val_accuracy: 0.9062 - val_loss: 0.3624 - learning_rate: 5.0000e-04
# Epoch 42/100
# 43/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9513 - loss: 0.1571
# Epoch 42: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9524 - loss: 0.1547 - val_accuracy: 0.9006 - val_loss: 0.3678 - learning_rate: 5.0000e-04
# Epoch 43/100
# 42/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9472 - loss: 0.1469
# Epoch 43: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9474 - loss: 0.1493 - val_accuracy: 0.9119 - val_loss: 0.3527 - learning_rate: 5.0000e-04
# Epoch 44/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9493 - loss: 0.1514
# Epoch 44: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9517 - loss: 0.1469 - val_accuracy: 0.9091 - val_loss: 0.3832 - learning_rate: 5.0000e-04
# Epoch 45/100
# 36/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9540 - loss: 0.1405
# Epoch 45: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9538 - loss: 0.1393 - val_accuracy: 0.9062 - val_loss: 0.3731 - learning_rate: 5.0000e-04
# Epoch 46/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9588 - loss: 0.1330
# Epoch 46: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9588 - loss: 0.1330 - val_accuracy: 0.9091 - val_loss: 0.3664 - learning_rate: 2.5000e-04
# Epoch 47/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9561 - loss: 0.1334
# Epoch 47: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9559 - loss: 0.1352 - val_accuracy: 0.9091 - val_loss: 0.3490 - learning_rate: 2.5000e-04
# Epoch 48/100
# 36/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9592 - loss: 0.1313
# Epoch 48: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9581 - loss: 0.1295 - val_accuracy: 0.9034 - val_loss: 0.3574 - learning_rate: 2.5000e-04
# Epoch 49/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9595 - loss: 0.1273
# Epoch 49: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9602 - loss: 0.1276 - val_accuracy: 0.9119 - val_loss: 0.3569 - learning_rate: 2.5000e-04
# Epoch 50/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9603 - loss: 0.1262
# Epoch 50: val_accuracy did not improve from 0.91761
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9595 - loss: 0.1283 - val_accuracy: 0.9062 - val_loss: 0.3605 - learning_rate: 2.5000e-04
# Epoch 51/100
# 42/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9554 - loss: 0.1294
# Epoch 51: val_accuracy improved from 0.91761 to 0.92614, saving model to ./phase2_90sec.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 51: finished saving model to ./phase2_90sec.h5
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9566 - loss: 0.1271 - val_accuracy: 0.9261 - val_loss: 0.3557 - learning_rate: 2.5000e-04
# Epoch 52/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9586 - loss: 0.1198
# Epoch 52: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9581 - loss: 0.1220 - val_accuracy: 0.9261 - val_loss: 0.3560 - learning_rate: 2.5000e-04
# Epoch 53/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9604 - loss: 0.1255
# Epoch 53: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9602 - loss: 0.1249 - val_accuracy: 0.9006 - val_loss: 0.3680 - learning_rate: 2.5000e-04
# Epoch 54/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9611 - loss: 0.1210
# Epoch 54: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9616 - loss: 0.1220 - val_accuracy: 0.9091 - val_loss: 0.3578 - learning_rate: 1.2500e-04
# Epoch 55/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9604 - loss: 0.1183
# Epoch 55: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9609 - loss: 0.1178 - val_accuracy: 0.9006 - val_loss: 0.3662 - learning_rate: 1.2500e-04
# Epoch 56/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9688 - loss: 0.1166
# Epoch 56: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9652 - loss: 0.1206 - val_accuracy: 0.9091 - val_loss: 0.3576 - learning_rate: 1.2500e-04
# Epoch 57/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9595 - loss: 0.1161
# Epoch 57: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9595 - loss: 0.1161 - val_accuracy: 0.9091 - val_loss: 0.3569 - learning_rate: 1.2500e-04
# Epoch 58/100
# 38/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9638 - loss: 0.1123
# Epoch 58: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9616 - loss: 0.1174 - val_accuracy: 0.9148 - val_loss: 0.3529 - learning_rate: 1.2500e-04
# Epoch 59/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9638 - loss: 0.1175
# Epoch 59: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9638 - loss: 0.1175 - val_accuracy: 0.9148 - val_loss: 0.3540 - learning_rate: 1.2500e-04
# Epoch 60/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9664 - loss: 0.1124
# Epoch 60: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9659 - loss: 0.1151 - val_accuracy: 0.9091 - val_loss: 0.3576 - learning_rate: 1.2500e-04
# Epoch 61/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9645 - loss: 0.1203
# Epoch 61: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9659 - loss: 0.1145 - val_accuracy: 0.9091 - val_loss: 0.3582 - learning_rate: 1.2500e-04
# Epoch 62/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9634 - loss: 0.1127
# Epoch 62: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9645 - loss: 0.1131 - val_accuracy: 0.9233 - val_loss: 0.3579 - learning_rate: 6.2500e-05
# Epoch 63/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9657 - loss: 0.1132
# Epoch 63: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9666 - loss: 0.1119 - val_accuracy: 0.9261 - val_loss: 0.3616 - learning_rate: 6.2500e-05
# Epoch 64/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9641 - loss: 0.1138
# Epoch 64: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9652 - loss: 0.1126 - val_accuracy: 0.9148 - val_loss: 0.3616 - learning_rate: 6.2500e-05
# Epoch 65/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9649 - loss: 0.1120
# Epoch 65: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9652 - loss: 0.1113 - val_accuracy: 0.9119 - val_loss: 0.3613 - learning_rate: 6.2500e-05
# Epoch 66/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9672 - loss: 0.1110
# Epoch 66: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9666 - loss: 0.1112 - val_accuracy: 0.9062 - val_loss: 0.3633 - learning_rate: 6.2500e-05
# Epoch 67/100
# 38/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9663 - loss: 0.1132
# Epoch 67: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9659 - loss: 0.1119 - val_accuracy: 0.9091 - val_loss: 0.3641 - learning_rate: 6.2500e-05
# Epoch 68/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9659 - loss: 0.1117
# Epoch 68: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9659 - loss: 0.1117 - val_accuracy: 0.9233 - val_loss: 0.3625 - learning_rate: 6.2500e-05
# Epoch 69/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9648 - loss: 0.1108
# Epoch 69: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9652 - loss: 0.1100 - val_accuracy: 0.9119 - val_loss: 0.3621 - learning_rate: 6.2500e-05
# Epoch 70/100
# 38/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9655 - loss: 0.1115
# Epoch 70: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9673 - loss: 0.1101 - val_accuracy: 0.9091 - val_loss: 0.3627 - learning_rate: 3.1250e-05
# Epoch 71/100
# 39/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9736 - loss: 0.1030
# Epoch 71: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9709 - loss: 0.1087 - val_accuracy: 0.9091 - val_loss: 0.3639 - learning_rate: 3.1250e-05
# Epoch 72/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.1070
# Epoch 72: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9680 - loss: 0.1086 - val_accuracy: 0.9233 - val_loss: 0.3615 - learning_rate: 3.1250e-05
# Epoch 73/100
# 36/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9661 - loss: 0.1068
# Epoch 73: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9652 - loss: 0.1090 - val_accuracy: 0.9233 - val_loss: 0.3611 - learning_rate: 3.1250e-05
# Epoch 74/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9716 - loss: 0.1092
# Epoch 74: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9716 - loss: 0.1092 - val_accuracy: 0.9119 - val_loss: 0.3619 - learning_rate: 3.1250e-05
# Epoch 75/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9672 - loss: 0.1085
# Epoch 75: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9680 - loss: 0.1081 - val_accuracy: 0.9233 - val_loss: 0.3619 - learning_rate: 3.1250e-05
# Epoch 76/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9734 - loss: 0.1056
# Epoch 76: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9709 - loss: 0.1082 - val_accuracy: 0.9233 - val_loss: 0.3630 - learning_rate: 3.1250e-05
# Epoch 77/100
# 42/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9688 - loss: 0.1104
# Epoch 77: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9701 - loss: 0.1078 - val_accuracy: 0.9233 - val_loss: 0.3622 - learning_rate: 3.1250e-05
# Epoch 78/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9718 - loss: 0.1076
# Epoch 78: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1074 - val_accuracy: 0.9233 - val_loss: 0.3620 - learning_rate: 1.5625e-05
# Epoch 79/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9695 - loss: 0.1099
# Epoch 79: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9716 - loss: 0.1073 - val_accuracy: 0.9233 - val_loss: 0.3622 - learning_rate: 1.5625e-05
# Epoch 80/100
# 43/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9709 - loss: 0.1087
# Epoch 80: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9716 - loss: 0.1074 - val_accuracy: 0.9233 - val_loss: 0.3633 - learning_rate: 1.5625e-05
# Epoch 81/100
# 36/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.1063
# Epoch 81: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9701 - loss: 0.1073 - val_accuracy: 0.9233 - val_loss: 0.3625 - learning_rate: 1.5625e-05
# Epoch 82/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9718 - loss: 0.1077
# Epoch 82: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1070 - val_accuracy: 0.9233 - val_loss: 0.3637 - learning_rate: 1.5625e-05
# Epoch 83/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9649 - loss: 0.1094
# Epoch 83: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9666 - loss: 0.1070 - val_accuracy: 0.9233 - val_loss: 0.3629 - learning_rate: 1.5625e-05
# Epoch 84/100
# 43/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9709 - loss: 0.1085
# Epoch 84: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9716 - loss: 0.1069 - val_accuracy: 0.9233 - val_loss: 0.3636 - learning_rate: 1.5625e-05
# Epoch 85/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9703 - loss: 0.1100
# Epoch 85: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9723 - loss: 0.1070 - val_accuracy: 0.9233 - val_loss: 0.3625 - learning_rate: 1.5625e-05
# Epoch 86/100
# 38/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9704 - loss: 0.1071
# Epoch 86: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1065 - val_accuracy: 0.9233 - val_loss: 0.3635 - learning_rate: 1.0000e-05
# Epoch 87/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9695 - loss: 0.1085
# Epoch 87: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9709 - loss: 0.1066 - val_accuracy: 0.9233 - val_loss: 0.3631 - learning_rate: 1.0000e-05
# Epoch 88/100
# 42/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9710 - loss: 0.1081
# Epoch 88: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9716 - loss: 0.1064 - val_accuracy: 0.9233 - val_loss: 0.3632 - learning_rate: 1.0000e-05
# Epoch 89/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9719 - loss: 0.1069
# Epoch 89: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1064 - val_accuracy: 0.9233 - val_loss: 0.3634 - learning_rate: 1.0000e-05
# Epoch 90/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9713 - loss: 0.1071
# Epoch 90: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1062 - val_accuracy: 0.9233 - val_loss: 0.3637 - learning_rate: 1.0000e-05
# Epoch 91/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9703 - loss: 0.1106
# Epoch 91: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1065 - val_accuracy: 0.9233 - val_loss: 0.3634 - learning_rate: 1.0000e-05
# Epoch 92/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9718 - loss: 0.1060
# Epoch 92: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1063 - val_accuracy: 0.9233 - val_loss: 0.3640 - learning_rate: 1.0000e-05
# Epoch 93/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9703 - loss: 0.1084
# Epoch 93: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1063 - val_accuracy: 0.9233 - val_loss: 0.3636 - learning_rate: 1.0000e-05
# Epoch 94/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9695 - loss: 0.1097
# Epoch 94: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1061 - val_accuracy: 0.9233 - val_loss: 0.3636 - learning_rate: 1.0000e-05
# Epoch 95/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9711 - loss: 0.1047
# Epoch 95: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1063 - val_accuracy: 0.9233 - val_loss: 0.3637 - learning_rate: 1.0000e-05
# Epoch 96/100
# 37/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9679 - loss: 0.1138
# Epoch 96: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1060 - val_accuracy: 0.9233 - val_loss: 0.3635 - learning_rate: 1.0000e-05
# Epoch 97/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9719 - loss: 0.1081
# Epoch 97: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1061 - val_accuracy: 0.9233 - val_loss: 0.3634 - learning_rate: 1.0000e-05
# Epoch 98/100
# 40/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9711 - loss: 0.1073
# Epoch 98: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1061 - val_accuracy: 0.9233 - val_loss: 0.3643 - learning_rate: 1.0000e-05
# Epoch 99/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9718 - loss: 0.1053
# Epoch 99: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1060 - val_accuracy: 0.9233 - val_loss: 0.3640 - learning_rate: 1.0000e-05
# Epoch 100/100
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9718 - loss: 0.1065
# Epoch 100: val_accuracy did not improve from 0.92614
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9716 - loss: 0.1060 - val_accuracy: 0.9233 - val_loss: 0.3633 - learning_rate: 1.0000e-05

# %% [markdown]
# ## Evaluate (float32)

# %%
cp_model = load_model('./phase2_90sec.h5')
cp_model.evaluate(X_test, y_test, batch_size=1000)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9417 - loss: 0.2608
# [0.26075759530067444, 0.9417218565940857]

# %%
y_pred = cp_model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

print(classification_report(y_test, y_pred_classes, target_names=list(CLASSES), digits=4))
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#               precision    recall  f1-score   support
#
#       benign     0.9809    0.9554    0.9680       269
#        sysrv     0.7807    0.8725    0.8241       102
#        xmrig     0.9744    0.9702    0.9723       235
#        mirai     0.9448    0.9195    0.9320       149
#
#     accuracy                         0.9417       755
#    macro avg     0.9202    0.9294    0.9241       755
# weighted avg     0.9447    0.9417    0.9428       755

# %%
conf_matrix = confusion_matrix(y_test, y_pred_classes)
conf_matrix_df = pd.DataFrame(conf_matrix, index=list(CLASSES), columns=list(CLASSES))
print("Confusion Matrix:")
print(conf_matrix_df)
# Out:
# Confusion Matrix:
#         benign  sysrv  xmrig  mirai
# benign     257      9      2      1
# sysrv        5     89      3      5
# xmrig        0      5    228      2
# mirai        0     11      1    137

# %% [markdown]
# ## Q15 Quantization

# %%
def scale_for_q15(w):
    absmax = np.abs(w).max()
    if absmax <= 1.0:
        return w, 1
    scale = 1
    while absmax / scale > 1.0:
        scale *= 2
    return w / scale, scale

def to_q15(x):
    return np.clip(np.round(x * 32768.0), -32768, 32767).astype(np.int64)

def to_q15_bias(x):
    return np.clip(np.round(x * 32768.0), -2**31, 2**31 - 1).astype(np.int64)

def quantize_weights_flatten(model):
    conv_layers = [l for l in model.layers if 'conv1d' in l.name]
    dense_layers = [l for l in model.layers if l.name.startswith('dense')]
    c1_w_f, c1_b_f = conv_layers[0].get_weights()
    c2_w_f, c2_b_f = conv_layers[1].get_weights()
    c3_w_f, c3_b_f = conv_layers[2].get_weights()
    d_w_f, d_b_f = dense_layers[0].get_weights()
    fc_w_f, fc_b_f = dense_layers[1].get_weights()
    c1_w = np.transpose(c1_w_f[:, 0, :], (1, 0))
    c2_w = np.transpose(c2_w_f, (2, 1, 0))
    c3_w = np.transpose(c3_w_f, (2, 1, 0))
    d_w = d_w_f.T
    fc_w = fc_w_f.T
    out = {}
    for name, w, b in [('conv1', c1_w, c1_b_f), ('conv2', c2_w, c2_b_f), ('conv3', c3_w, c3_b_f),
                        ('dense', d_w, d_b_f), ('fc2', fc_w, fc_b_f)]:
        w_s, scale = scale_for_q15(w)
        out[f'{name}_w'] = to_q15(w_s)
        out[f'{name}_b'] = to_q15_bias(b / scale)
    return out

def windows_1d(a, out_len, k, stride, axis):
    a = np.ascontiguousarray(a)
    shape = list(a.shape); shape[axis] = out_len; shape = shape + [k]
    strides = list(a.strides); ts = strides[axis]
    strides[axis] = ts * stride; strides = strides + [ts]
    return as_strided(a, shape=shape, strides=strides)

def q15_forward(qw, X, s1, s2, s3, seq_len):
    c1w, c1b = qw['conv1_w'].astype(np.int64), qw['conv1_b'].astype(np.int64)
    c2w, c2b = qw['conv2_w'].astype(np.int64), qw['conv2_b'].astype(np.int64)
    c3w, c3b = qw['conv3_w'].astype(np.int64), qw['conv3_b'].astype(np.int64)
    dw, db = qw['dense_w'].astype(np.int64), qw['dense_b'].astype(np.int64)
    fcw, fcb = qw['fc2_w'].astype(np.int64), qw['fc2_b'].astype(np.int64)
    F1, K1 = c1w.shape
    F2, _, K2 = c2w.shape
    F3, _, K3 = c3w.shape
    c1out = (seq_len - K1) // s1 + 1
    c2out = (c1out - K2) // s2 + 1
    c3out = (c2out - K3) // s3 + 1
    Xq = np.clip(np.round(X * 32768), -32768, 32767).astype(np.int64)
    win1 = windows_1d(Xq, c1out, K1, s1, axis=1)
    a1 = np.maximum(0, (np.einsum('ntk,fk->nft', win1, c1w) >> 15) + c1b[None, :, None])
    a1c = np.clip(a1, -32768, 32767)
    win2 = windows_1d(a1c, c2out, K2, s2, axis=2)
    a2 = np.maximum(0, (np.einsum('nctk,fck->nft', win2, c2w) >> 15) + c2b[None, :, None])
    a2c = np.clip(a2, -32768, 32767)
    win3 = windows_1d(a2c, c3out, K3, s3, axis=2)
    a3 = np.maximum(0, (np.einsum('nctk,fck->nft', win3, c3w) >> 15) + c3b[None, :, None])
    a3c = np.clip(a3, -32768, 32767)
    N = X.shape[0]
    flat = a3c.reshape(N, F3 * c3out)
    hidden = np.clip(np.maximum(0, (flat @ dw.T >> 15) + db[None, :]), -32768, 32767)
    logits = (hidden @ fcw.T >> 15) + fcb[None, :]
    return np.argmax(logits, axis=1)

# %% [markdown]
# ## Evaluate (Q15)

# %%
qw = quantize_weights_flatten(cp_model)
X_test_flat = X_test.reshape(-1, VECTOR_LENGTH)
y_pred_q15 = q15_forward(qw, X_test_flat, 10, 1, 1, VECTOR_LENGTH)

print(classification_report(y_test, y_pred_q15, target_names=list(CLASSES), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#       benign     0.9919    0.9071    0.9476       269
#        sysrv     0.6992    0.9118    0.7915       102
#        xmrig     0.9744    0.9702    0.9723       235
#        mirai     0.9577    0.9128    0.9347       149
#
#     accuracy                         0.9285       755
#    macro avg     0.9058    0.9254    0.9115       755
# weighted avg     0.9402    0.9285    0.9316       755

# %%
conf_matrix_q15 = confusion_matrix(y_test, y_pred_q15)
conf_matrix_q15_df = pd.DataFrame(conf_matrix_q15, index=list(CLASSES), columns=list(CLASSES))
print("Confusion Matrix (Q15):")
print(conf_matrix_q15_df)
# Out:
# Confusion Matrix (Q15):
#         benign  sysrv  xmrig  mirai
# benign     244     22      2      1
# sysrv        2     93      3      4
# xmrig        0      6    228      1
# mirai        0     12      1    136
